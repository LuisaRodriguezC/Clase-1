# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisaRodriguezC/Clase-1/blob/main/Prim_entrega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Luisa Fernanda Rodriguez Candamil**
# ### Codigo. 63191162
# ### *Finanzas y Comercio Internacional*

# %% [markdown]
# # **First Part**
#
# Picth
#
# Format - .ipynb
#
# Contents:
#
# ### 1. Variable:
#
# ### 1.1. Name and description.
#
# The variables considered for this dataset would be:
#
# 1. The time period from 2015 to 2020.
#
# 2. The unit of measurement will be "counts" for thefts and bribes in Latin America, specifically in Chile, Colombia, Ecuador, Mexico, Panama, and Uruguay.
#
#
# ### 1.2. Period or dates. Frequency. Individuals.
#    * The variables being considered will cover a time period from 2015 to 2020, which means they will include data that corresponds to this time interval. Regarding their unit of measure, "counts" will be used to record the number of occurrences or events of interest in the database. This will allow for a precise and quantifiable record of the data, which in turn will facilitate the analysis and interpretation of the results obtained.

# %% [markdown]
# ### 1.3. Sources (with links).
#
# [DATABASE LINK](https://dataunodc.un.org/dp-crime-corruption-offences)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Goal of the DV
# ### 2.1. Story.
#
# * The database focuses mainly on robberies and bribes in Latin America, specifically in Chile, Colombia, Ecuador, Mexico, Panama, and Uruguay, and is interesting for several reasons. It allows for identifying specific patterns and trends in each country, making comparisons between them, promoting transparency and accountability, and facilitating cooperation and information exchange among different countries. It can also be useful for gaining a better understanding of the phenomenon of corruption and crime in the region and enabling more rigorous and precise research on the topic.
#
#
# ### 2.2. Audience.
#
# * The information in this database of robberies and bribes in Latin America can be useful for a varied audience, such as government institutions and international organizations, companies and corporations, researchers and academics, media, citizens, and civil society. Each of them can use this information for different purposes, such as designing policies and strategies, assessing risks, investigating specific cases, monitoring the performance of governments and businesses, and making demands for greater transparency and accountability.
#
# ### 2.3. Justify the DV type.
#
# * The bar chart is a good option to represent the database with specific variables of robberies and bribes in Latin America because it allows comparing the amount or frequency of these crimes between different countries.
# In a bar chart, each bar represents a category or country, and the height of the bar represents the amount of robberies and bribes in that category. This allows for a quick visual comparison between different categories and countries.
# Additionally, the bar chart is easy to understand and is suitable for audiences without experience in interpreting complex data. For these reasons, the bar chart is a popular and widely used type of visualization for representing numerical and frequency data in many fields, including economics, politics, health, and education.

# %% [markdown]
# ## Examples
#
# ### 3.1. Example A.
# **Diagnosed cases of coronavirus in Spain**
# ### 2.1. Story.
# * Starting from March 28th, 2022, it only records cases in the population considered "vulnerable." It allows for a clear and concise view of the evolution of cases over time in Spain. This can help identify patterns and trends in the virus's spread, which is useful for decision-making and implementing effective public policies to contain its spread. It can also be relevant to inform the general public and raise awareness about the importance of following prevention and precautionary measures.
# ### 2.2. Audience.
# * It could be relevant to a wide variety of audiences, including citizens interested in the evolution of the pandemic, media covering public and social interest issues, health professionals who need to be aware of the epidemiological situation, government authorities and decision-makers in public health, as well as researchers and academics studying the pandemic and its consequences.
#
# ### 2.3. Justify the DV type.
# * The frequency polygon is a useful visualization tool for the topic of diagnosed cases of coronavirus in Spain because it allows for displaying the distribution of data on a continuous range, which can be helpful in identifying patterns and trends over time. Additionally, it can help identify peaks and valleys in the number of diagnosed cases.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.2. Example B.
# **Women killed by gender violence**
#
# This other graph shows the comparison of deaths so far this year
#
# ### 2.1. Story.
#  The graphical visualization of the topic of women killed by gender violence is important because it allows us to understand the magnitude of the problem, its geographical distribution, and trends over time. Additionally, it helps to identify specific patterns and can be an effective way to raise awareness and promote action and prevention.
#
# ### 2.2. Audience.
# The information about women killed by gender violence would be relevant to a wide variety of audiences, including groups working for the defense of women's rights and the elimination of gender violence, media covering issues of public and social interest, researchers and academics studying gender violence and its consequences, and citizens interested in the social issue of gender violence and its impact on society. In general, anyone or entity interested in knowing and addressing the problem of gender violence and its implications could consider this information relevant.
#
# ### 2.3. Justify the DV type.
#
# A bar chart is a good visualization tool for the topic of women killed by gender violence because it can display the number of cases in a clear and concise manner. The length of each bar represents the quantity of cases, making it easy to compare and identify trends over time or across regions.
#
#
# ![image.png](data:image/png;base64,...)
